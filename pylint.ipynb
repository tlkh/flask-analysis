# %%
# !pylint ./flask/src/flask/*
# Out:
# ************* Module flask.app
# flask/src/flask/app.py:1:0: C0302: Too many lines in module (1956/1000) (too-many-lines)
# flask/src/flask/app.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# flask/src/flask/app.py:8:0: E0401: Unable to import 'werkzeug.datastructures' (import-error)
# flask/src/flask/app.py:9:0: E0401: Unable to import 'werkzeug.datastructures' (import-error)
# flask/src/flask/app.py:10:0: E0401: Unable to import 'werkzeug.exceptions' (import-error)
# flask/src/flask/app.py:11:0: E0401: Unable to import 'werkzeug.exceptions' (import-error)
# flask/src/flask/app.py:12:0: E0401: Unable to import 'werkzeug.exceptions' (import-error)
# flask/src/flask/app.py:13:0: E0401: Unable to import 'werkzeug.exceptions' (import-error)
# flask/src/flask/app.py:14:0: E0401: Unable to import 'werkzeug.routing' (import-error)
# flask/src/flask/app.py:15:0: E0401: Unable to import 'werkzeug.routing' (import-error)
# ...
